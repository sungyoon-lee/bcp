# %% [markdown]
# # MNIST-TRAIN

# %%
# !python main_mnist.py --prefix 'tutorial'
# Out:
# Setting CUDA_VISIBLE_DEVICES to 0
# Namespace(alpha=0.395, augmentation=False, batch_size=50, bce=False, cuda_ids=0, data='mnist', drop_last=False, epochs=60, epsilon=1.58, epsilon_infty=0.1, epsilon_pgd=1.58, epsilon_train=1.58, epsilon_train_infty=0.1, gamma=0.1, kappa=0, kappa_schedule_length=20, linfty=False, lr=0.0003, lr_scheduler='multistep', method='BCP', model='large', model_factor=8, momentum=0.9, niter=100, norm='2', normalization=False, opt='adam', opt_iter=10, prefix='models/mnist/tutorial_large_BCP_data_mnist_epochs_60_epsilon_train_1.58_lr_0.0003_norm_2_opt_adam_opt_iter_10_rampup_20_sniter_1_starting_kappa_0.99_warmup_1', print=False, rampup=20, real_time=False, resnet_N=1, resnet_factor=1, save=True, schedule_length=20, seed=0, shuffle=True, sniter=1, starting_epsilon=0.001, starting_kappa=0.99, step_size=10, test_batch_size=50, test_opt_iter=10000, test_pth=None, test_sniter=5000, verbose=200, warmup=1, wd_list=[21, 30, 40], weight_decay=0.0005)
# ...

# %%
# !python evaluation_mnist.py --test_pth models/mnist/tutorial_large_BCP_data_mnist_epochs_60_epsilon_train_1.58_lr_0.0003_norm_2_opt_adam_opt_iter_10_rampup_20_sniter_1_starting_kappa_0.99_warmup_1_best.pth
# Out:
# Setting CUDA_VISIBLE_DEVICES to 0
# ...
