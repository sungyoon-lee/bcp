# %% [markdown]
# # train_mnist.py

# %%
# !python train_mnist.py --cuda_ids 3 --prefix '10152159'
# Out:
# Setting CUDA_VISIBLE_DEVICES to 3
# 2020-10-15 22:25:44.434301
# ...

# %% [markdown]
# # evaluate_mnist.py

# %%
# !python evaluate_mnist.py --test_pth models/mnist/10152159_large_BCP_data_mnist_epochs_60_epsilon_train_1.58_lr_0.0003_opt_adam_opt_iter_10_rampup_20_sniter_1_starting_kappa_1.0_train_method_BCP_warmup_1_best.pth --cuda_ids 3
# Out:
# Setting CUDA_VISIBLE_DEVICES to 3
# ...
